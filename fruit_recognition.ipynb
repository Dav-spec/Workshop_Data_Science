# %%
import cv2; print (cv2.__version__)
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
# Out:
# 4.5.5

# %%
img = cv2.imread("Apple/0_100.jpg")
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
plt.savefig('Vision 1.png', dpi=350)

# %%
img = cv2.imread('Apple/0_100.jpg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')
plt.savefig('Vision 2.png', dpi=350)

# %%
img = cv2.imread('Apple/0_100.jpg')
gray = np.float32(cv2.cvtColor(img,cv2.COLOR_BGR2GRAY))
dst = cv2.cornerHarris(gray,10,1,0.1)
plt.imshow(dst, cmap='gray')
plt.savefig('Vision 3.png', dpi=350)

# %%
img = cv2.imread('Apple/0_100.jpg')
gray = np.float32(cv2.cvtColor(img,cv2.COLOR_BGR2GRAY))
dst = cv2.cornerHarris(gray,10,1,0.1)
for i in [0.1, 0.01, 0.001, 0.0001]:
    img[dst>i*dst.max()]=[255,0,0]
    plt.title('Harris Corner Detection, Th = {}'.format(i))
    plt.imshow(img)
    plt.savefig('Vision 4_{}.png'.format(i), dpi=350)
    plt.show()

# %%
population_pie={
  "data": [
    {
      "values": pop_reg.Population,
      "labels": pop_reg.Regions,
      "domain": {"x": [0, .8],
                "y": [0, .8]},
      "name": "Population Rate of Regions",
      "hoverinfo":"label+percent+name",
      "hole": .2,
      "type": "pie"
    },],
  "layout": {
        "title":"Population Rate of Regions",
        "annotations": [
            { "font": { "size": 20},
              "showarrow": False,
              "text": "Population Rate of Regions",
                "x": 0.27,
                "y": 1
            },
        ]
    }
}
    
iplot(population_pie)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16172/2844686052.py in <module>
#       2   "data": [
#       3     {
# ----> 4       "values": pop_reg.Population,
#       5       "labels": pop_reg.Regions,
#       6       "domain": {"x": [0, .8],
#
# NameError: name 'pop_reg' is not defined

# %% [markdown]
# # Calculate the number of Apples and Bananas and Visualize them

# %%
import os

def count_files(folder_name):
        Files = os.listdir(folder_name)
        count = 0
        for file in Files:
            count+=1
        print("There are " +str(count) + " pictures of " + folder_name + 's')

count_files('Apple')
count_files('Banana')
# Out:
# There are 2017 pictures of Apples
# There are 3704 pictures of Bananas

# %%
df = pd.read_excel("number_of_fruits.xlsx")
df
# Out:
#     Fruit  fileNumber
# 0   Apple        2017
# 1  Banana        3704

# %%
total_of_counts = df.fileNumber.sum()
total_of_counts
# Out:
# 5721

# %%
def autopct_format(precentege_value):
    print(precentege_value)
    return '{:.1f}%\n{:.0f}'.format(precentege_value, total_of_counts*precentege_value/100)

# %%
# Set lables and Values
labels = df.Fruit
values = df.fileNumber
explode = [0.1, 0]

# %%
# visualize the pie chart
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')

ax.pie(values, labels = labels, autopct=autopct_format, explode = explode, textprops={'fontsize' : 14})
plt.show()
# Out:
# 35.256072878837585
# 64.74392414093018

# %% [markdown]
# # Resize all the pictures in the folder to the same dimensions

# %%
from PIL import Image

img=Image.open(r"C:\Users\User\Desktop\Workshop_Data_Science\Apple\181red applee02401181.png") #480x322
name = img.filename
splitted_name = name.split("\\")
print(name.split("\\"))
len(splitted_name)
file_name = splitted_name[len(splitted_name)-1]
file_name
img.size
img
img = img.resize((100,100), Image.ANTIALIAS)
img.size #100x100
img
img.save('\APPLE_RESIZE\'' + filename)
img
# Out:
# ['C:', 'Users', 'User', 'Desktop', 'Workshop_Data_Science', 'Apple', '181red applee02401181.png']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16172/2134603758.py in <module>
#      13 img.size #100x100
#      14 img
# ---> 15 img.save('\APPLE_RESIZE\'' + filename)
#      16 img
#
# NameError: name 'filename' is not defined

# %%
from PIL import Image
import glob
import os

#lst_imgs = [i for i in glob.glob('Apple\*.png')]
#print(lst_imgs)

#It creates a folder named ltl if doesn't exist
if not "ltl" in os.listdir():
    os.mkdir("ltl")

for i in lst_imgs:
    img = Image.open(i)
    img.resize((100,100), Image.ANTIALIAS)
    file_name = i[7:-4] + "_ltl.png"
    img.save("ltl\\" + file_name)

print("Done")
os.startfile("ltl")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16172/1347966376.py in <module>
#      11
#      12 for i in lst_imgs:
# ---> 13     img = Image.open(i)
#      14     img.resize((100,100), Image.ANTIALIAS)
#      15     file_name = i[7:-4] + "_ltl.png"
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# -> 2975         fp = builtins.open(filename, "rb")
#    2976         exclusive_fp = True
#    2977
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Apple\\102red applee00901102.png'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16172/682456463.py in <module>
#       1 for i in lst_imgs:
# ----> 2     img = Image.close(i)
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in __getattr__(name)
#      75                 )
#      76                 return categories[name]
# ---> 77         raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#      78
#      79
#
# AttributeError: module 'PIL.Image' has no attribute 'close'

# %%
from PIL import Image
import glob
import os

#List all img files in the Apple dir
lst_imgs_png = [i for i in glob.glob("Apple\*.png")]
#print(lst_imgs)

if not "ltl" in os.listdir():
    os.mkdir("ltl")

for i in lst_imgs_png:
    img = Image.open(i)
    img = img.resize((128,128), Image.ANTIALIAS)
    img.save("ltl\\" + i[7:-4] + "_ltl.png")
    
print("Done")
os.startfile("ltl")
# Out:
# Done

# %%
lst_imgs_jpg = [i for i in glob.glob("Apple\*.jpg")]

if not "ltl" in os.listdir():
    os.mkdir("ltl")

for i in lst_imgs_jpg:
    img = Image.open(i)
    img = img.resize((128,128), Image.ANTIALIAS)
    img.save("ltl\\" + i[7:-4] + "_ltl.jpg")
    
print("Done")
os.startfile("ltl")


lst_imgs_jpg = [i for i in glob.glob("Apple\*.jpg")]
# Out:
# Done

# %%
lst_imgs = [i for i in glob.glob("Apple\*")]

def resize (folder_path, new_folder_name):
    if not "resize_apple" in os.listdir():
        os.mkdir("resize_apple")

    for i in lst_imgs:
        img = Image.open(i)
        img = img.resize((150,150), Image.ANTIALIAS)
        img.save("resize_apple\\" + i[7:-4] + "_resized.jpg")

    print("Done")
    os.startfile("resize_apple")
# Out:
# Done

# %%
def resize (folder_path, new_folder_name):
    lst_imgs = [i for i in glob.glob(folder_path + "\*")]
    if not new_folder_name in os.listdir():
        os.mkdir(new_folder_name)
    count = 1
    for i in lst_imgs:
        img = Image.open(i)
        img = img.resize((150,150), Image.ANTIALIAS)
        img.save(new_folder_name + "\\" + str(count) + "_resized.jpg")
        count+=1
    print("Done")
    os.startfile(new_folder_name)

#resize('Apple','Apple_resize')
resize('Banana','Banana_resize')
# Out:
# Done

# %% [markdown]
# # Train the CNN model

# %%
def cut_df(df, number_of_parts, part):
# Return a part of the dataframe
# For example, if a dataframe has 10 rows and we want to return a part of them
# if it is cut in two, it will return the first 5 rows or the last 5 rows depending the part wanted

# Args:
#     df (pandas.DataFrame): The dataframe to cut a part of
#     number_of_parts (int): In how many parts should the dataframe be cut
#     part (int): The part of the dataframe to return

    if part < 1:
        print("Error, the part should be at least 1")
    elif part > number_of_parts:
        print("Error, the part cannot be higher than the number_of_parts")
        
    number_imgs_each_part = int(df.shape[0]/number_of_parts)
    idx1 = (part-1) * number_imgs_each_part
    idx2 = part * number_imgs_each_part
    return df.iloc[idx1:idx2]

def load_img(df):
# Load the images using their contained in the dataframe df
# Return a list of images and a list with the labels of the images
    img_paths = df["path"].values
    img_labels = df["label"].values
    X = []
    y = []
    
    for i,path in enumerate(img_paths):
        img =  plt.imread(path)
        img = cv2.resize(img, (150,150))
        label = img_labels[i]
        X.append(img)
        y.append(label)
    return np.array(X),np.array(y)

# %%
def create_model():
    shape_img = (150,150,3)
    
    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=(3,3),input_shape=shape_img, activation='relu', padding = 'same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=shape_img, activation='relu', padding = 'same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=shape_img, activation='relu', padding = 'same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=shape_img, activation='relu', padding = 'same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=shape_img, activation='relu', padding = 'same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=shape_img, activation='relu', padding = 'same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())

    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))

    model.add(Dense(len(mapper_fruit_names)))
    model.add(Activation('softmax'))

    model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
    
    return model

# %%
def from_categorical(lst):
    """
    Inverse of to_categorical
    Example: [[0,0,0,1,0], [1,0,0,0,0]] => [3,0]
    """
    
    lst = lst.tolist()
    lst2 = []
    for x in lst:
        lst2.append(x.index(max(x)))
    return lst2

def display_stats(y_test, pred):
# Display prediction statistics
    print(f"### Result of the predictions using {len(y_test)} test data ###\n")
    y_test_class = from_categorical(y_test)
    print("Classification Report:\n")
    print(classification_report(y_test_class, pred))
    print("\nConfusion Matrix:\n\n")
    print(confusion_matrix(y_test_class, pred))
    print("\n")
    printmd(f"# Accuracy: {round(accuracy_score(y_test_class, pred),5)}")
    
def plot_training(model):
    history = pd.DataFrame(model.history.history)
    history[["accuracy","val_accuracy"]].plot()
    plt.title("Training results")
    plt.xlabel("# epoch")
    plt.show()

# %%
import keras
from keras import Sequential
model = create_model()
hists = []

# The model will be trained with one part of the data.
# There isn't enough RAM on Kaggle to handle all the data.
# In the next chapter a generator will be used
# to "feed" the ANN step by step.
# For Kaggle set divisor <= 5. 1/5 of the data will be used
divisor = 5

start_time = time.time()
X_train, y_train = load_img(cut_df(df,divisor,1))
y_train = to_categorical(y_train)

# If the ANN doesn't increase its prediction accuracy on the validation data after 
# 10 epochs, stop the training and take the best of the ANN.
callbacks = [EarlyStopping(monitor='val_loss', patience=20),
             ModelCheckpoint(filepath='best_model.h5', monitor='val_loss', save_best_only=True)]

model.fit(X_train, y_train, batch_size=128, epochs=100, callbacks=callbacks, validation_split = 0.1, verbose = 1)
hists.append(model.history.history)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13484/67141533.py in <module>
# ----> 1 import keras
#       2 from keras import Sequential
#       3 model = create_model()
#       4 hists = []
#       5
#
# ~\anaconda3\lib\site-packages\keras\__init__.py in <module>
#      19 """
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python import tf2
#      22 from keras import distribute
#      23
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
pip install keras
# Out:
# Collecting keras
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
# Installing collected packages: keras
# Successfully installed keras-2.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
